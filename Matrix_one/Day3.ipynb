# %%
#!pip install datadotworld
#!pip install datadotworld[pandas]

# %%
#!dw configure
# Out:
# API token (obtained at: https://data.world/settings/advanced): eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJwcm9kLXVzZXItY2xpZW50OmdyZWczMjEiLCJpc3MiOiJhZ2VudDpncmVnMzIxOjphN2I3MjAzZC1iMTg4LTRiMDEtYmNiMS1kNWY1Mjg1Y2E3OTQiLCJpYXQiOjE1ODE1MDQ5NDQsInJvbGUiOlsidXNlcl9hcGlfcmVhZCIsInVzZXJfYXBpX3dyaXRlIl0sImdlbmVyYWwtcHVycG9zZSI6dHJ1ZSwic2FtbCI6e319.GOSvAW5GqnJWq3hwftgPxcIpaBWMQKSnjGfPTTU-xdHXZK4XAXZeLAKJUZY77RR5hq8a9JOFYhlyxqzCNkuh0g

# %%
from google.colab import drive
import pandas as pd
import numpy as np

import datadotworld as dw

# %%
#drive.mount("/content/drive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd "drive/My Drive/Colab Notebooks/Matrix"
# Out:
# /content/drive/My Drive/Colab Notebooks/Matrix

# %%
# !mkdir data

# %%
echo 'data' > .gitignore
# Out:
#   File "<ipython-input-6-190efbcadad9>", line 1
#     echo 'data' > .gitignore
#               ^
# SyntaxError: invalid syntax

# %%
# !echo 'data' > .gitignore

# %%
# !git add .gitignore

# %%
data = dw.load_dataset("https://data.world/datafiniti/mens-shoe-prices")

# %%
data.head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-80c7d069447b> in <module>()
# ----> 1 data.head(5)
#
# AttributeError: 'LocalDataset' object has no attribute 'head'

# %%
data = dw.load_dataset("datafiniti/mens-shoe-prices")

# %%
data.dataframes
# Out:
# LazyLoadedDict({'7004_1': LazyLoadedValue(<pandas.DataFrame>)})

# %%
df = data.dataframes['7004_1']
# Out:
# /usr/local/lib/python3.6/dist-packages/datadotworld/models/dataset.py:209: UserWarning: Unable to set data frame dtypes automatically using 7004_1 schema. Data types may need to be adjusted manually. Error: Integer column has NA values in column 10
#   'Error: {}'.format(resource_name, e))
# /usr/local/lib/python3.6/dist-packages/datadotworld/util.py:121: DtypeWarning: Columns (39,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return self._loader_func()

# %%
df.shape
# Out:
# (19387, 48)

# %%
df.sample(5)
# Out:
#                          id asins        brand  ...  vin websiteids  weight
# 4489   AVpfRCSR1cnluZ0-hbgx   NaN  New Balance  ...  NaN        NaN     NaN
# 9143   AVpfYQ2SilAPnD_xau05   NaN     Converse  ...  NaN        NaN     NaN
# 14373  AVpf2q-J1cnluZ0-sfwC   NaN  Stacy Adams  ...  NaN        NaN     NaN
# 13072  AVpfZMld1cnluZ0-j_hD   NaN  New Balance  ...  NaN        NaN     NaN
# 6709   AVpe9Tt3LJeJML43zM4T   NaN   Jewelryweb  ...  NaN        NaN     NaN
#
# [5 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'vin', 'websiteids', 'weight'],
#       dtype='object')

# %%
df.prices_currency.value_counts(normalize = True)
# Out:
# USD                                                   0.959246
# AUD                                                   0.017503
# CAD                                                   0.015691
# EUR                                                   0.005541
# GBP                                                   0.001139
# new                                                   0.000155
# UnbeatableSale.com, Inc. - Walmart.com                0.000155
# PalmBeach Jewelry - Walmart.com                       0.000155
# New with box                                          0.000155
# Wholesale Costume and Party Supplies - Walmart.com    0.000104
# SHOEBACCA LTD. - Walmart.com                          0.000052
# Shoes.com                                             0.000052
# New without tags                                      0.000052
# Name: prices_currency, dtype: float64

# %%
df_usd = df[df.prices_currency == "USD"].copy()

# %%
df_usd.shape
# Out:
# (18524, 48)

# %%
df_usd['prices_amountmin'].astype(np.float)

# %%
# !git add Matrix_one/Day3

# %%
# !git commit -m "Add Men's Shoe Prices data set from data.world"
# Out:
# [master f932c79] Add Men's Shoe Prices data set from data.world
#  2 files changed, 2 insertions(+), 129 deletions(-)
#  rewrite .gitignore (100%)
#  create mode 100644 Matrix_one/Day3

# %%
# !git config --global user.email "grzegorzgrodzki3@gmail.com"
# !git config --global user.name "Grzegorz"

# %%
# !git push -u origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (5/5), 9.11 KiB | 1.52 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0)
# To https://github.com/GGrodzki/Matrix.git
#    5871152..f932c79  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
ls
# Out:
# data/  HelloGithub.ipynb  LICENSE  Matrix_one/  README.md

# %%
# !git add matrix_one/day3.ipynb
# Out:
# fatal: pathspec 'matrix_one/day3.ipynb' did not match any files

# %%
# !git add Matrix_one/day3.ipynb
